# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split,cross_val_score

# %%
df=pd.read_csv("kaggle_data.csv")
df
# Out:
#    Unnamed: 0       team_1       team_2        stage  Winner_toss  \
# 0     Match_1    Australia  SouthAfrica  Group_stage    Australia
# 1     Match_2      England      Windies  Group_stage      England
# 2     Match_3     Srilanka   Bangladesh  Group_stage     Srilanka
# 3     Match_4     Pakistan        India  Group_stage     Pakistan
# 4     Match_5  Afghanistan     Scotland  Group_stage  Afghanistan
# 5     Match_6  SouthAfrica      Windies  Group_stage  SouthAfrica
# 6     Match_7     Pakistan  New_Zealand  Group_stage     Pakistan
# 7     Match_8      England   Bangladesh  Group_stage   Bangladesh
# 8     Match_9      Namibia     ScotLand  Group_stage      Namibia
# 9    Match_10    Australia     Srilanka  Group_stage    Australia
# 10   Match_11      Windies   Bangladesh  Group_stage   Bangladesh
# 11   Match_12     Pakistan  Afghanistan  Group_stage  Afghanistan
# 12   Match_13  SouthAfrica     Srilanka  Group_stage  SouthAfrica
# 13   Match_14      England    Australia  Group_stage      England
# 14   Match_15  Afghanistan      Namibia  Group_stage  Afghanistan
# 15   Match_16  New_Zealand        India  Group_stage  New_Zealand
# 16   Match_17      England     Srilanka  Group_stage     Srilanka
# 17   Match_18  SouthAfrica   Bangladesh  Group_stage  SouthAfrica
# 18   Match_19     Pakistan      Namibia  Group_stage     Pakistan
# 19   Match_20  New_Zealand     ScotLand  Group_stage  New_Zealand
# 20   Match_21        India  Afghanistan  Group_stage  Afghanistan
# 21   Match_22    Australia   Bangladesh  Group_stage    Australia
# 22   Match_23     Srilanka      Windies  Group_stage      Windies
# 23   Match_24  New_Zealand      Namibia  Group_stage      Namibia
# 24   Match_25        India     ScotLand  Group_stage        India
# 25   Match_26    Australia      Windies  Group_stage    Australia
# 26   Match_27  SouthAfrica      England  Group_stage      England
# 27   Match_28  New_Zealand  Afghanistan  Group_stage  Afghanistan
# 28   Match_29     Pakistan     ScotLand  Group_stage     Pakistan
# 29   Match_30        India      Namibia  Group_stage        India
# 30   Match_31  New_Zealand      England   Semi_Final  New_Zealand
# 31   Match_32    Australia     Pakistan   Semi_Final    Australia
# 32   Match_33    Australia  New_Zealand        Final    Australia
#
#    Toss_descision       time      venue  avg_temperature        best_bowler  \
# 0        Fielding  afternoon  Abu_Dhabi               30     Josh_Hazlewood
# 1        Fielding    evening      Dubai               33        Adil_Rashid
# 2        Fielding  afternoon    Sharjah               34   Shakib_al_Hassan
# 3        Fielding    evening      Dubai               34       Shaheen_shah
# 4         Batting    evening    Sharjah               33   Mujeeb_ur_Rehman
# 5        Fielding  afternoon      Dubai               33  Dwaine_Pretorious
# 6        Fielding    evening    Sharjah               29         Haris_Rauf
# 7         Batting  afternoon  Abu_Dhabi               30        Tymal_Mills
# 8        Fielding    evening  Abu_Dhabi               29  Ruben_Trumpelmann
# 9        Fielding    evening      Dubai               28         Adam_Zampa
# 10       Fielding  afternoon    Sharjah               30     Shoriful_Islam
# 11        Batting    evening      Dubai               30         Imad_Wasim
# 12       Fielding  afternoon    Sharjah               31     Tabraiz_Shamsi
# 13       Fielding    evening      Dubai               30       Criss_Jordan
# 14        Batting  afternoon  Abu_Dhabi               30       Hamid_Hassan
# 15       Fielding    evening      Dubai               30        Trent_Boult
# 16       Fielding    evening    Sharjah               28  Wanindu_Hasaranga
# 17       Fielding  afternoon  Abu_Dhabi               30      Anrich_Nortje
# 18        Batting    evening  Abu_Dhabi               29         Imad_wasim
# 19       Fielding  afternoon      Dubai               29     Safyaan_Sharif
# 20       Fielding    evening  Abu_Dhabi               29     Mohammed Shami
# 21       Fielding  afternoon      Dubai               29         Adam_Zampa
# 22       Fielding    evening  Abu_Dhabi               28  Wanindu_Hasaranga
# 23       Fielding  afternoon    Sharjah               28        Tim_Southee
# 24       Fielding    evening      Dubai               28    Ravindra_Jadeja
# 25       Fielding  afternoon  Abu_Dhabi               20     Josh_Hazlewood
# 26       Fielding    evening    Sharjah               27      Kagiso_Rabada
# 27        Batting  afternoon  Abu_Dhabi               29        Trent_Boult
# 28        Batting    evening    Sharjah               27        Shadab_Khan
# 29       Fielding    evening      Dubai               28    Ravindra_Jadeja
# 30       Fielding    evening  Abu_Dhabi               28   Liam_Livingstone
# 31       Fielding    evening      Dubai               29        Shadab_Khan
# 32       Fielding    evening      Dubai               26     Josh_Hazlewood
#
#     ... best_bowler_country            best_batter  batting_hand  \
# 0   ...           Australia          Aiden_Markram         Right
# 1   ...             England            Jos_Buttler         Right
# 2   ...          Bangladesh       Charith_Asalanka          Left
# 3   ...            Pakistan        Muhammad_Rizwan         Right
# 4   ...         Afghanistan      Najibullah_Zadran          Left
# 5   ...         SouthAfrica             Evin_Lewis          Left
# 6   ...            Pakistan        Muhammad_Rizwan         Right
# 7   ...             England              Jason_Roy         Right
# 8   ...             Namibia          Michael_Leask         Right
# 9   ...           Australia           David_Warner          Left
# 10  ...          Bangladesh              Liton_Das         Right
# 11  ...            Pakistan             Babar_Azam         Right
# 12  ...         SouthAfrica        Pathum_Nissanka         Right
# 13  ...             England            Jos_Buttler         Right
# 14  ...         Afghanistan       Mohammad_Shahzad         Right
# 15  ...         New_Zealand         Daryl_Mitchell         Right
# 16  ...            Srilanka            Jos_Buttler         Right
# 17  ...         SouthAfrica          Temaba_Bavuma         Right
# 18  ...            Pakistan        Muhammad_Rizwan         Right
# 19  ...            ScotLand         Martin_Guptill         Right
# 20  ...               India           Rohit_Sharma         Right
# 21  ...           Australia            Aaron_Finch         Right
# 22  ...            Srilanka        Shimron_Hetmyer          Left
# 23  ...         New_Zealand         Glenn_Phillips         Right
# 24  ...               India               KL_Rahul         Right
# 25  ...           Australia           David_Warner          Left
# 26  ...         SouthAfrica  Rassie van der Dussen         Right
# 27  ...         New_Zealand      Najibullah_Zadran          Left
# 28  ...            Pakistan             Babar_Azam         Right
# 29  ...               India           Rohit_Sharma         Right
# 30  ...             England         Daryl_Mitchell         Right
# 31  ...            Pakistan        Muhammad_Rizwan         Right
# 32  ...           Australia        Kane_Williamson         Right
#
#     high_indvidual_scores strike_rate best_batter_team target  \
# 0                      40      111.10      SouthAfrica    119
# 1                      24      109.10          England     56
# 2                      80      163.20         Srilanka    172
# 3                      79      143.60         Pakistan    152
# 4                      59      173.53      Afghanistan    191
# 5                      56      160.00          Windies    144
# 6                      33       97.06         Pakistan    135
# 7                      61      160.50          England    125
# 8                      44      162.90         ScotLand    110
# 9                      65      154.76        Australia    155
# 10                     40      102.30       Bangladesh    140
# 11                     51      108.50         Pakistan    148
# 12                     72      124.14         Srilanka    143
# 13                     71      221.80          England    126
# 14                     45      136.36      Afghanistan    161
# 15                     49      140.00      New_Zealand    111
# 16                    101      150.75          England    164
# 17                     31      110.70      SouthAfrica     85
# 18                     79      158.00         Pakistan    190
# 19                     93      166.07      New_Zealand    173
# 20                     74      157.45            India    211
# 21                     40      200.00        Australia     74
# 22                     81      150.00          Windies    190
# 23                     39      185.71      New_Zealand    164
# 24                     50      263.16            India     86
# 25                     89      158.93        Australia    158
# 26                     94      156.67      SouthAfrica    190
# 27                     73      152.08      Afghanistan    125
# 28                     66      140.43         Pakistan    190
# 29                     56      151.35            India    133
# 30                     72      153.19      New_Zealand    167
# 31                     67      128.85         Pakistan    177
# 32                     85      177.08      New_Zealand    173
#
#     target_achieved    Player_of_the_match       Winner
# 0                 1         Josh_Hazlewood    Australia
# 1                 1              Moeen_Ali      England
# 2                 1       Charith_Asalanka     Srilanka
# 3                 1           Shaheen_shah     Pakistan
# 4                 0       Mujeeb_ur_Rehman  Afghanistan
# 5                 1          Anrich_Nortje  SouthAfrica
# 6                 1             Haris_Rauf     Pakistan
# 7                 1              Jason_Roy      England
# 8                 1      Ruben_Trumpelmann      Namibia
# 9                 1             Adam_Zampa    Australia
# 10                1        Nicholas_Pooran      Windies
# 11                1               Asif_Ali     Pakistan
# 12                1         Tabraiz_Shamsi  SouthAfrica
# 13                1           Chris_Jordan      England
# 14                0          Naveen_ul_Haq  Afghanistan
# 15                1            Trent_Boult  New_Zealand
# 16                0            Jos_Buttler      England
# 17                1          Kagiso_Rabada  SouthAfrica
# 18                0        Muhammad_Rizwan     Pakistan
# 19                0         Martin_Guptill  New_Zealand
# 20                0           Rohit_Sharma        India
# 21                1             Adam_Zampa    Australia
# 22                0        Chrith_Adalanka     Srilanka
# 23                0          James_Neesham  New_Zealand
# 24                1        Ravindra_Jadeja        India
# 25                1           David_Warner    Australia
# 26                0  Rassie_van_der_Dussen  SouthAfrica
# 27                1            Trent_Boult  New_Zealand
# 28                0           Shoaib_Malik     Pakistan
# 29                1        Ravindra_Jadeja        India
# 30                1         Daryl_Mitchell  New_Zealand
# 31                1           Matthew_Wade    Australia
# 32                1         Mitchell_Marsh    Australia
#
# [33 rows x 24 columns]

# %%
df.shape
# Out:
# (33, 24)

# %%
df = df.rename(columns = {'Unnamed: 0' : 'Match Number'})
df
# Out:
#    Match Number       team_1       team_2        stage  Winner_toss  \
# 0       Match_1    Australia  SouthAfrica  Group_stage    Australia
# 1       Match_2      England      Windies  Group_stage      England
# 2       Match_3     Srilanka   Bangladesh  Group_stage     Srilanka
# 3       Match_4     Pakistan        India  Group_stage     Pakistan
# 4       Match_5  Afghanistan     Scotland  Group_stage  Afghanistan
# 5       Match_6  SouthAfrica      Windies  Group_stage  SouthAfrica
# 6       Match_7     Pakistan  New_Zealand  Group_stage     Pakistan
# 7       Match_8      England   Bangladesh  Group_stage   Bangladesh
# 8       Match_9      Namibia     ScotLand  Group_stage      Namibia
# 9      Match_10    Australia     Srilanka  Group_stage    Australia
# 10     Match_11      Windies   Bangladesh  Group_stage   Bangladesh
# 11     Match_12     Pakistan  Afghanistan  Group_stage  Afghanistan
# 12     Match_13  SouthAfrica     Srilanka  Group_stage  SouthAfrica
# 13     Match_14      England    Australia  Group_stage      England
# 14     Match_15  Afghanistan      Namibia  Group_stage  Afghanistan
# 15     Match_16  New_Zealand        India  Group_stage  New_Zealand
# 16     Match_17      England     Srilanka  Group_stage     Srilanka
# 17     Match_18  SouthAfrica   Bangladesh  Group_stage  SouthAfrica
# 18     Match_19     Pakistan      Namibia  Group_stage     Pakistan
# 19     Match_20  New_Zealand     ScotLand  Group_stage  New_Zealand
# 20     Match_21        India  Afghanistan  Group_stage  Afghanistan
# 21     Match_22    Australia   Bangladesh  Group_stage    Australia
# 22     Match_23     Srilanka      Windies  Group_stage      Windies
# 23     Match_24  New_Zealand      Namibia  Group_stage      Namibia
# 24     Match_25        India     ScotLand  Group_stage        India
# 25     Match_26    Australia      Windies  Group_stage    Australia
# 26     Match_27  SouthAfrica      England  Group_stage      England
# 27     Match_28  New_Zealand  Afghanistan  Group_stage  Afghanistan
# 28     Match_29     Pakistan     ScotLand  Group_stage     Pakistan
# 29     Match_30        India      Namibia  Group_stage        India
# 30     Match_31  New_Zealand      England   Semi_Final  New_Zealand
# 31     Match_32    Australia     Pakistan   Semi_Final    Australia
# 32     Match_33    Australia  New_Zealand        Final    Australia
#
#    Toss_descision       time      venue  avg_temperature        best_bowler  \
# 0        Fielding  afternoon  Abu_Dhabi               30     Josh_Hazlewood
# 1        Fielding    evening      Dubai               33        Adil_Rashid
# 2        Fielding  afternoon    Sharjah               34   Shakib_al_Hassan
# 3        Fielding    evening      Dubai               34       Shaheen_shah
# 4         Batting    evening    Sharjah               33   Mujeeb_ur_Rehman
# 5        Fielding  afternoon      Dubai               33  Dwaine_Pretorious
# 6        Fielding    evening    Sharjah               29         Haris_Rauf
# 7         Batting  afternoon  Abu_Dhabi               30        Tymal_Mills
# 8        Fielding    evening  Abu_Dhabi               29  Ruben_Trumpelmann
# 9        Fielding    evening      Dubai               28         Adam_Zampa
# 10       Fielding  afternoon    Sharjah               30     Shoriful_Islam
# 11        Batting    evening      Dubai               30         Imad_Wasim
# 12       Fielding  afternoon    Sharjah               31     Tabraiz_Shamsi
# 13       Fielding    evening      Dubai               30       Criss_Jordan
# 14        Batting  afternoon  Abu_Dhabi               30       Hamid_Hassan
# 15       Fielding    evening      Dubai               30        Trent_Boult
# 16       Fielding    evening    Sharjah               28  Wanindu_Hasaranga
# 17       Fielding  afternoon  Abu_Dhabi               30      Anrich_Nortje
# 18        Batting    evening  Abu_Dhabi               29         Imad_wasim
# 19       Fielding  afternoon      Dubai               29     Safyaan_Sharif
# 20       Fielding    evening  Abu_Dhabi               29     Mohammed Shami
# 21       Fielding  afternoon      Dubai               29         Adam_Zampa
# 22       Fielding    evening  Abu_Dhabi               28  Wanindu_Hasaranga
# 23       Fielding  afternoon    Sharjah               28        Tim_Southee
# 24       Fielding    evening      Dubai               28    Ravindra_Jadeja
# 25       Fielding  afternoon  Abu_Dhabi               20     Josh_Hazlewood
# 26       Fielding    evening    Sharjah               27      Kagiso_Rabada
# 27        Batting  afternoon  Abu_Dhabi               29        Trent_Boult
# 28        Batting    evening    Sharjah               27        Shadab_Khan
# 29       Fielding    evening      Dubai               28    Ravindra_Jadeja
# 30       Fielding    evening  Abu_Dhabi               28   Liam_Livingstone
# 31       Fielding    evening      Dubai               29        Shadab_Khan
# 32       Fielding    evening      Dubai               26     Josh_Hazlewood
#
#     ... best_bowler_country            best_batter  batting_hand  \
# 0   ...           Australia          Aiden_Markram         Right
# 1   ...             England            Jos_Buttler         Right
# 2   ...          Bangladesh       Charith_Asalanka          Left
# 3   ...            Pakistan        Muhammad_Rizwan         Right
# 4   ...         Afghanistan      Najibullah_Zadran          Left
# 5   ...         SouthAfrica             Evin_Lewis          Left
# 6   ...            Pakistan        Muhammad_Rizwan         Right
# 7   ...             England              Jason_Roy         Right
# 8   ...             Namibia          Michael_Leask         Right
# 9   ...           Australia           David_Warner          Left
# 10  ...          Bangladesh              Liton_Das         Right
# 11  ...            Pakistan             Babar_Azam         Right
# 12  ...         SouthAfrica        Pathum_Nissanka         Right
# 13  ...             England            Jos_Buttler         Right
# 14  ...         Afghanistan       Mohammad_Shahzad         Right
# 15  ...         New_Zealand         Daryl_Mitchell         Right
# 16  ...            Srilanka            Jos_Buttler         Right
# 17  ...         SouthAfrica          Temaba_Bavuma         Right
# 18  ...            Pakistan        Muhammad_Rizwan         Right
# 19  ...            ScotLand         Martin_Guptill         Right
# 20  ...               India           Rohit_Sharma         Right
# 21  ...           Australia            Aaron_Finch         Right
# 22  ...            Srilanka        Shimron_Hetmyer          Left
# 23  ...         New_Zealand         Glenn_Phillips         Right
# 24  ...               India               KL_Rahul         Right
# 25  ...           Australia           David_Warner          Left
# 26  ...         SouthAfrica  Rassie van der Dussen         Right
# 27  ...         New_Zealand      Najibullah_Zadran          Left
# 28  ...            Pakistan             Babar_Azam         Right
# 29  ...               India           Rohit_Sharma         Right
# 30  ...             England         Daryl_Mitchell         Right
# 31  ...            Pakistan        Muhammad_Rizwan         Right
# 32  ...           Australia        Kane_Williamson         Right
#
#     high_indvidual_scores strike_rate best_batter_team target  \
# 0                      40      111.10      SouthAfrica    119
# 1                      24      109.10          England     56
# 2                      80      163.20         Srilanka    172
# 3                      79      143.60         Pakistan    152
# 4                      59      173.53      Afghanistan    191
# 5                      56      160.00          Windies    144
# 6                      33       97.06         Pakistan    135
# 7                      61      160.50          England    125
# 8                      44      162.90         ScotLand    110
# 9                      65      154.76        Australia    155
# 10                     40      102.30       Bangladesh    140
# 11                     51      108.50         Pakistan    148
# 12                     72      124.14         Srilanka    143
# 13                     71      221.80          England    126
# 14                     45      136.36      Afghanistan    161
# 15                     49      140.00      New_Zealand    111
# 16                    101      150.75          England    164
# 17                     31      110.70      SouthAfrica     85
# 18                     79      158.00         Pakistan    190
# 19                     93      166.07      New_Zealand    173
# 20                     74      157.45            India    211
# 21                     40      200.00        Australia     74
# 22                     81      150.00          Windies    190
# 23                     39      185.71      New_Zealand    164
# 24                     50      263.16            India     86
# 25                     89      158.93        Australia    158
# 26                     94      156.67      SouthAfrica    190
# 27                     73      152.08      Afghanistan    125
# 28                     66      140.43         Pakistan    190
# 29                     56      151.35            India    133
# 30                     72      153.19      New_Zealand    167
# 31                     67      128.85         Pakistan    177
# 32                     85      177.08      New_Zealand    173
#
#     target_achieved    Player_of_the_match       Winner
# 0                 1         Josh_Hazlewood    Australia
# 1                 1              Moeen_Ali      England
# 2                 1       Charith_Asalanka     Srilanka
# 3                 1           Shaheen_shah     Pakistan
# 4                 0       Mujeeb_ur_Rehman  Afghanistan
# 5                 1          Anrich_Nortje  SouthAfrica
# 6                 1             Haris_Rauf     Pakistan
# 7                 1              Jason_Roy      England
# 8                 1      Ruben_Trumpelmann      Namibia
# 9                 1             Adam_Zampa    Australia
# 10                1        Nicholas_Pooran      Windies
# 11                1               Asif_Ali     Pakistan
# 12                1         Tabraiz_Shamsi  SouthAfrica
# 13                1           Chris_Jordan      England
# 14                0          Naveen_ul_Haq  Afghanistan
# 15                1            Trent_Boult  New_Zealand
# 16                0            Jos_Buttler      England
# 17                1          Kagiso_Rabada  SouthAfrica
# 18                0        Muhammad_Rizwan     Pakistan
# 19                0         Martin_Guptill  New_Zealand
# 20                0           Rohit_Sharma        India
# 21                1             Adam_Zampa    Australia
# 22                0        Chrith_Adalanka     Srilanka
# 23                0          James_Neesham  New_Zealand
# 24                1        Ravindra_Jadeja        India
# 25                1           David_Warner    Australia
# 26                0  Rassie_van_der_Dussen  SouthAfrica
# 27                1            Trent_Boult  New_Zealand
# 28                0           Shoaib_Malik     Pakistan
# 29                1        Ravindra_Jadeja        India
# 30                1         Daryl_Mitchell  New_Zealand
# 31                1           Matthew_Wade    Australia
# 32                1         Mitchell_Marsh    Australia
#
# [33 rows x 24 columns]

# %%
df = df.set_index('Match Number')
df
# Out:
#                    team_1       team_2        stage  Winner_toss  \
# Match Number
# Match_1         Australia  SouthAfrica  Group_stage    Australia
# Match_2           England      Windies  Group_stage      England
# Match_3          Srilanka   Bangladesh  Group_stage     Srilanka
# Match_4          Pakistan        India  Group_stage     Pakistan
# Match_5       Afghanistan     Scotland  Group_stage  Afghanistan
# Match_6       SouthAfrica      Windies  Group_stage  SouthAfrica
# Match_7          Pakistan  New_Zealand  Group_stage     Pakistan
# Match_8           England   Bangladesh  Group_stage   Bangladesh
# Match_9           Namibia     ScotLand  Group_stage      Namibia
# Match_10        Australia     Srilanka  Group_stage    Australia
# Match_11          Windies   Bangladesh  Group_stage   Bangladesh
# Match_12         Pakistan  Afghanistan  Group_stage  Afghanistan
# Match_13      SouthAfrica     Srilanka  Group_stage  SouthAfrica
# Match_14          England    Australia  Group_stage      England
# Match_15      Afghanistan      Namibia  Group_stage  Afghanistan
# Match_16      New_Zealand        India  Group_stage  New_Zealand
# Match_17          England     Srilanka  Group_stage     Srilanka
# Match_18      SouthAfrica   Bangladesh  Group_stage  SouthAfrica
# Match_19         Pakistan      Namibia  Group_stage     Pakistan
# Match_20      New_Zealand     ScotLand  Group_stage  New_Zealand
# Match_21            India  Afghanistan  Group_stage  Afghanistan
# Match_22        Australia   Bangladesh  Group_stage    Australia
# Match_23         Srilanka      Windies  Group_stage      Windies
# Match_24      New_Zealand      Namibia  Group_stage      Namibia
# Match_25            India     ScotLand  Group_stage        India
# Match_26        Australia      Windies  Group_stage    Australia
# Match_27      SouthAfrica      England  Group_stage      England
# Match_28      New_Zealand  Afghanistan  Group_stage  Afghanistan
# Match_29         Pakistan     ScotLand  Group_stage     Pakistan
# Match_30            India      Namibia  Group_stage        India
# Match_31      New_Zealand      England   Semi_Final  New_Zealand
# Match_32        Australia     Pakistan   Semi_Final    Australia
# Match_33        Australia  New_Zealand        Final    Australia
#
#              Toss_descision       time      venue  avg_temperature  \
# Match Number
# Match_1            Fielding  afternoon  Abu_Dhabi               30
# Match_2            Fielding    evening      Dubai               33
# Match_3            Fielding  afternoon    Sharjah               34
# Match_4            Fielding    evening      Dubai               34
# Match_5             Batting    evening    Sharjah               33
# Match_6            Fielding  afternoon      Dubai               33
# Match_7            Fielding    evening    Sharjah               29
# Match_8             Batting  afternoon  Abu_Dhabi               30
# Match_9            Fielding    evening  Abu_Dhabi               29
# Match_10           Fielding    evening      Dubai               28
# Match_11           Fielding  afternoon    Sharjah               30
# Match_12            Batting    evening      Dubai               30
# Match_13           Fielding  afternoon    Sharjah               31
# Match_14           Fielding    evening      Dubai               30
# Match_15            Batting  afternoon  Abu_Dhabi               30
# Match_16           Fielding    evening      Dubai               30
# Match_17           Fielding    evening    Sharjah               28
# Match_18           Fielding  afternoon  Abu_Dhabi               30
# Match_19            Batting    evening  Abu_Dhabi               29
# Match_20           Fielding  afternoon      Dubai               29
# Match_21           Fielding    evening  Abu_Dhabi               29
# Match_22           Fielding  afternoon      Dubai               29
# Match_23           Fielding    evening  Abu_Dhabi               28
# Match_24           Fielding  afternoon    Sharjah               28
# Match_25           Fielding    evening      Dubai               28
# Match_26           Fielding  afternoon  Abu_Dhabi               20
# Match_27           Fielding    evening    Sharjah               27
# Match_28            Batting  afternoon  Abu_Dhabi               29
# Match_29            Batting    evening    Sharjah               27
# Match_30           Fielding    evening      Dubai               28
# Match_31           Fielding    evening  Abu_Dhabi               28
# Match_32           Fielding    evening      Dubai               29
# Match_33           Fielding    evening      Dubai               26
#
#                     best_bowler bowling_arm  ... best_bowler_country  \
# Match Number                                 ...
# Match_1          Josh_Hazlewood       Right  ...           Australia
# Match_2             Adil_Rashid       Right  ...             England
# Match_3        Shakib_al_Hassan        Left  ...          Bangladesh
# Match_4            Shaheen_shah        Left  ...            Pakistan
# Match_5        Mujeeb_ur_Rehman       Right  ...         Afghanistan
# Match_6       Dwaine_Pretorious       Right  ...         SouthAfrica
# Match_7              Haris_Rauf       Right  ...            Pakistan
# Match_8             Tymal_Mills        Left  ...             England
# Match_9       Ruben_Trumpelmann        Left  ...             Namibia
# Match_10             Adam_Zampa       Right  ...           Australia
# Match_11         Shoriful_Islam        Left  ...          Bangladesh
# Match_12             Imad_Wasim        Left  ...            Pakistan
# Match_13         Tabraiz_Shamsi        Left  ...         SouthAfrica
# Match_14           Criss_Jordan       Right  ...             England
# Match_15           Hamid_Hassan       Right  ...         Afghanistan
# Match_16            Trent_Boult        Left  ...         New_Zealand
# Match_17      Wanindu_Hasaranga       Right  ...            Srilanka
# Match_18          Anrich_Nortje       Right  ...         SouthAfrica
# Match_19             Imad_wasim        Left  ...            Pakistan
# Match_20         Safyaan_Sharif       Right  ...            ScotLand
# Match_21         Mohammed Shami       Right  ...               India
# Match_22             Adam_Zampa       Right  ...           Australia
# Match_23      Wanindu_Hasaranga       Right  ...            Srilanka
# Match_24            Tim_Southee       Right  ...         New_Zealand
# Match_25        Ravindra_Jadeja        Left  ...               India
# Match_26         Josh_Hazlewood       Right  ...           Australia
# Match_27          Kagiso_Rabada       Right  ...         SouthAfrica
# Match_28            Trent_Boult        Left  ...         New_Zealand
# Match_29            Shadab_Khan       Right  ...            Pakistan
# Match_30        Ravindra_Jadeja        Left  ...               India
# Match_31       Liam_Livingstone       Right  ...             England
# Match_32            Shadab_Khan       Right  ...            Pakistan
# Match_33         Josh_Hazlewood       Right  ...           Australia
#
#                         best_batter  batting_hand high_indvidual_scores  \
# Match Number
# Match_1               Aiden_Markram         Right                    40
# Match_2                 Jos_Buttler         Right                    24
# Match_3            Charith_Asalanka          Left                    80
# Match_4             Muhammad_Rizwan         Right                    79
# Match_5           Najibullah_Zadran          Left                    59
# Match_6                  Evin_Lewis          Left                    56
# Match_7             Muhammad_Rizwan         Right                    33
# Match_8                   Jason_Roy         Right                    61
# Match_9               Michael_Leask         Right                    44
# Match_10               David_Warner          Left                    65
# Match_11                  Liton_Das         Right                    40
# Match_12                 Babar_Azam         Right                    51
# Match_13            Pathum_Nissanka         Right                    72
# Match_14                Jos_Buttler         Right                    71
# Match_15           Mohammad_Shahzad         Right                    45
# Match_16             Daryl_Mitchell         Right                    49
# Match_17                Jos_Buttler         Right                   101
# Match_18              Temaba_Bavuma         Right                    31
# Match_19            Muhammad_Rizwan         Right                    79
# Match_20             Martin_Guptill         Right                    93
# Match_21               Rohit_Sharma         Right                    74
# Match_22                Aaron_Finch         Right                    40
# Match_23            Shimron_Hetmyer          Left                    81
# Match_24             Glenn_Phillips         Right                    39
# Match_25                   KL_Rahul         Right                    50
# Match_26               David_Warner          Left                    89
# Match_27      Rassie van der Dussen         Right                    94
# Match_28          Najibullah_Zadran          Left                    73
# Match_29                 Babar_Azam         Right                    66
# Match_30               Rohit_Sharma         Right                    56
# Match_31             Daryl_Mitchell         Right                    72
# Match_32            Muhammad_Rizwan         Right                    67
# Match_33            Kane_Williamson         Right                    85
#
#              strike_rate best_batter_team  target  target_achieved  \
# Match Number
# Match_1           111.10      SouthAfrica     119                1
# Match_2           109.10          England      56                1
# Match_3           163.20         Srilanka     172                1
# Match_4           143.60         Pakistan     152                1
# Match_5           173.53      Afghanistan     191                0
# Match_6           160.00          Windies     144                1
# Match_7            97.06         Pakistan     135                1
# Match_8           160.50          England     125                1
# Match_9           162.90         ScotLand     110                1
# Match_10          154.76        Australia     155                1
# Match_11          102.30       Bangladesh     140                1
# Match_12          108.50         Pakistan     148                1
# Match_13          124.14         Srilanka     143                1
# Match_14          221.80          England     126                1
# Match_15          136.36      Afghanistan     161                0
# Match_16          140.00      New_Zealand     111                1
# Match_17          150.75          England     164                0
# Match_18          110.70      SouthAfrica      85                1
# Match_19          158.00         Pakistan     190                0
# Match_20          166.07      New_Zealand     173                0
# Match_21          157.45            India     211                0
# Match_22          200.00        Australia      74                1
# Match_23          150.00          Windies     190                0
# Match_24          185.71      New_Zealand     164                0
# Match_25          263.16            India      86                1
# Match_26          158.93        Australia     158                1
# Match_27          156.67      SouthAfrica     190                0
# Match_28          152.08      Afghanistan     125                1
# Match_29          140.43         Pakistan     190                0
# Match_30          151.35            India     133                1
# Match_31          153.19      New_Zealand     167                1
# Match_32          128.85         Pakistan     177                1
# Match_33          177.08      New_Zealand     173                1
#
#                 Player_of_the_match       Winner
# Match Number
# Match_1              Josh_Hazlewood    Australia
# Match_2                   Moeen_Ali      England
# Match_3            Charith_Asalanka     Srilanka
# Match_4                Shaheen_shah     Pakistan
# Match_5            Mujeeb_ur_Rehman  Afghanistan
# Match_6               Anrich_Nortje  SouthAfrica
# Match_7                  Haris_Rauf     Pakistan
# Match_8                   Jason_Roy      England
# Match_9           Ruben_Trumpelmann      Namibia
# Match_10                 Adam_Zampa    Australia
# Match_11            Nicholas_Pooran      Windies
# Match_12                   Asif_Ali     Pakistan
# Match_13             Tabraiz_Shamsi  SouthAfrica
# Match_14               Chris_Jordan      England
# Match_15              Naveen_ul_Haq  Afghanistan
# Match_16                Trent_Boult  New_Zealand
# Match_17                Jos_Buttler      England
# Match_18              Kagiso_Rabada  SouthAfrica
# Match_19            Muhammad_Rizwan     Pakistan
# Match_20             Martin_Guptill  New_Zealand
# Match_21               Rohit_Sharma        India
# Match_22                 Adam_Zampa    Australia
# Match_23            Chrith_Adalanka     Srilanka
# Match_24              James_Neesham  New_Zealand
# Match_25            Ravindra_Jadeja        India
# Match_26               David_Warner    Australia
# Match_27      Rassie_van_der_Dussen  SouthAfrica
# Match_28                Trent_Boult  New_Zealand
# Match_29               Shoaib_Malik     Pakistan
# Match_30            Ravindra_Jadeja        India
# Match_31             Daryl_Mitchell  New_Zealand
# Match_32               Matthew_Wade    Australia
# Match_33             Mitchell_Marsh    Australia
#
# [33 rows x 23 columns]

# %%
df.describe()
# Out:
#        avg_temperature  most_individual_wickets    economy  \
# count        33.000000                33.000000  33.000000
# mean         29.272727                 2.878788   5.215758
# std           2.577217                 0.892944   2.187966
# min          20.000000                 1.000000   0.900000
# 25%          28.000000                 2.000000   4.000000
# 50%          29.000000                 3.000000   4.800000
# 75%          30.000000                 3.000000   6.250000
# max          34.000000                 5.000000  12.000000
#
#        high_indvidual_scores  strike_rate      target  target_achieved
# count              33.000000    33.000000   33.000000        33.000000
# mean               62.393939   152.402121  146.606061         0.696970
# std                20.135385    33.999070   37.136521         0.466694
# min                24.000000    97.060000   56.000000         0.000000
# 25%                45.000000   136.360000  125.000000         0.000000
# 50%                65.000000   153.190000  152.000000         1.000000
# 75%                79.000000   162.900000  173.000000         1.000000
# max               101.000000   263.160000  211.000000         1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, Match_1 to Match_33
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   team_1                   33 non-null     object
#  1   team_2                   33 non-null     object
#  2   stage                    33 non-null     object
#  3   Winner_toss              33 non-null     object
#  4   Toss_descision           33 non-null     object
#  5   time                     33 non-null     object
#  6   venue                    33 non-null     object
#  7   avg_temperature          33 non-null     int64
#  8   best_bowler              33 non-null     object
#  9   bowling_arm              33 non-null     object
#  10  bowling_style            33 non-null     object
#  11  most_individual_wickets  33 non-null     int64
#  12  economy                  33 non-null     float64
#  13  best_bowler_country      33 non-null     object
#  14  best_batter              33 non-null     object
#  15  batting_hand             33 non-null     object
#  16  high_indvidual_scores    33 non-null     int64
#  17  strike_rate              33 non-null     float64
#  18  best_batter_team         33 non-null     object
#  19  target                   33 non-null     int64
#  20  target_achieved          33 non-null     int64
#  21  Player_of_the_match      33 non-null     object
#  22  Winner                   33 non-null     object
# dtypes: float64(2), int64(5), object(16)
# memory usage: 6.2+ KB

# %%
p=df.corr()

# %%
sns.heatmap(p,annot=True)
plt.show()

# %%
df.target_achieved[df['target_achieved']==0]="Achieved"
df.target_achieved[df['target_achieved']==1]="Not Achieved"
# Out:
# /var/folders/j9/nxw6tr6x2630lrfnp_vmnv0m0000gn/T/ipykernel_11365/3795280417.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.target_achieved[df['target_achieved']==0]="Achieved"

# %%
df
# Out:
#                    team_1       team_2        stage  Winner_toss  \
# Match Number
# Match_1         Australia  SouthAfrica  Group_stage    Australia
# Match_2           England      Windies  Group_stage      England
# Match_3          Srilanka   Bangladesh  Group_stage     Srilanka
# Match_4          Pakistan        India  Group_stage     Pakistan
# Match_5       Afghanistan     Scotland  Group_stage  Afghanistan
# Match_6       SouthAfrica      Windies  Group_stage  SouthAfrica
# Match_7          Pakistan  New_Zealand  Group_stage     Pakistan
# Match_8           England   Bangladesh  Group_stage   Bangladesh
# Match_9           Namibia     ScotLand  Group_stage      Namibia
# Match_10        Australia     Srilanka  Group_stage    Australia
# Match_11          Windies   Bangladesh  Group_stage   Bangladesh
# Match_12         Pakistan  Afghanistan  Group_stage  Afghanistan
# Match_13      SouthAfrica     Srilanka  Group_stage  SouthAfrica
# Match_14          England    Australia  Group_stage      England
# Match_15      Afghanistan      Namibia  Group_stage  Afghanistan
# Match_16      New_Zealand        India  Group_stage  New_Zealand
# Match_17          England     Srilanka  Group_stage     Srilanka
# Match_18      SouthAfrica   Bangladesh  Group_stage  SouthAfrica
# Match_19         Pakistan      Namibia  Group_stage     Pakistan
# Match_20      New_Zealand     ScotLand  Group_stage  New_Zealand
# Match_21            India  Afghanistan  Group_stage  Afghanistan
# Match_22        Australia   Bangladesh  Group_stage    Australia
# Match_23         Srilanka      Windies  Group_stage      Windies
# Match_24      New_Zealand      Namibia  Group_stage      Namibia
# Match_25            India     ScotLand  Group_stage        India
# Match_26        Australia      Windies  Group_stage    Australia
# Match_27      SouthAfrica      England  Group_stage      England
# Match_28      New_Zealand  Afghanistan  Group_stage  Afghanistan
# Match_29         Pakistan     ScotLand  Group_stage     Pakistan
# Match_30            India      Namibia  Group_stage        India
# Match_31      New_Zealand      England   Semi_Final  New_Zealand
# Match_32        Australia     Pakistan   Semi_Final    Australia
# Match_33        Australia  New_Zealand        Final    Australia
#
#              Toss_descision       time      venue  avg_temperature  \
# Match Number
# Match_1            Fielding  afternoon  Abu_Dhabi               30
# Match_2            Fielding    evening      Dubai               33
# Match_3            Fielding  afternoon    Sharjah               34
# Match_4            Fielding    evening      Dubai               34
# Match_5             Batting    evening    Sharjah               33
# Match_6            Fielding  afternoon      Dubai               33
# Match_7            Fielding    evening    Sharjah               29
# Match_8             Batting  afternoon  Abu_Dhabi               30
# Match_9            Fielding    evening  Abu_Dhabi               29
# Match_10           Fielding    evening      Dubai               28
# Match_11           Fielding  afternoon    Sharjah               30
# Match_12            Batting    evening      Dubai               30
# Match_13           Fielding  afternoon    Sharjah               31
# Match_14           Fielding    evening      Dubai               30
# Match_15            Batting  afternoon  Abu_Dhabi               30
# Match_16           Fielding    evening      Dubai               30
# Match_17           Fielding    evening    Sharjah               28
# Match_18           Fielding  afternoon  Abu_Dhabi               30
# Match_19            Batting    evening  Abu_Dhabi               29
# Match_20           Fielding  afternoon      Dubai               29
# Match_21           Fielding    evening  Abu_Dhabi               29
# Match_22           Fielding  afternoon      Dubai               29
# Match_23           Fielding    evening  Abu_Dhabi               28
# Match_24           Fielding  afternoon    Sharjah               28
# Match_25           Fielding    evening      Dubai               28
# Match_26           Fielding  afternoon  Abu_Dhabi               20
# Match_27           Fielding    evening    Sharjah               27
# Match_28            Batting  afternoon  Abu_Dhabi               29
# Match_29            Batting    evening    Sharjah               27
# Match_30           Fielding    evening      Dubai               28
# Match_31           Fielding    evening  Abu_Dhabi               28
# Match_32           Fielding    evening      Dubai               29
# Match_33           Fielding    evening      Dubai               26
#
#                     best_bowler bowling_arm  ... best_bowler_country  \
# Match Number                                 ...
# Match_1          Josh_Hazlewood       Right  ...           Australia
# Match_2             Adil_Rashid       Right  ...             England
# Match_3        Shakib_al_Hassan        Left  ...          Bangladesh
# Match_4            Shaheen_shah        Left  ...            Pakistan
# Match_5        Mujeeb_ur_Rehman       Right  ...         Afghanistan
# Match_6       Dwaine_Pretorious       Right  ...         SouthAfrica
# Match_7              Haris_Rauf       Right  ...            Pakistan
# Match_8             Tymal_Mills        Left  ...             England
# Match_9       Ruben_Trumpelmann        Left  ...             Namibia
# Match_10             Adam_Zampa       Right  ...           Australia
# Match_11         Shoriful_Islam        Left  ...          Bangladesh
# Match_12             Imad_Wasim        Left  ...            Pakistan
# Match_13         Tabraiz_Shamsi        Left  ...         SouthAfrica
# Match_14           Criss_Jordan       Right  ...             England
# Match_15           Hamid_Hassan       Right  ...         Afghanistan
# Match_16            Trent_Boult        Left  ...         New_Zealand
# Match_17      Wanindu_Hasaranga       Right  ...            Srilanka
# Match_18          Anrich_Nortje       Right  ...         SouthAfrica
# Match_19             Imad_wasim        Left  ...            Pakistan
# Match_20         Safyaan_Sharif       Right  ...            ScotLand
# Match_21         Mohammed Shami       Right  ...               India
# Match_22             Adam_Zampa       Right  ...           Australia
# Match_23      Wanindu_Hasaranga       Right  ...            Srilanka
# Match_24            Tim_Southee       Right  ...         New_Zealand
# Match_25        Ravindra_Jadeja        Left  ...               India
# Match_26         Josh_Hazlewood       Right  ...           Australia
# Match_27          Kagiso_Rabada       Right  ...         SouthAfrica
# Match_28            Trent_Boult        Left  ...         New_Zealand
# Match_29            Shadab_Khan       Right  ...            Pakistan
# Match_30        Ravindra_Jadeja        Left  ...               India
# Match_31       Liam_Livingstone       Right  ...             England
# Match_32            Shadab_Khan       Right  ...            Pakistan
# Match_33         Josh_Hazlewood       Right  ...           Australia
#
#                         best_batter  batting_hand high_indvidual_scores  \
# Match Number
# Match_1               Aiden_Markram         Right                    40
# Match_2                 Jos_Buttler         Right                    24
# Match_3            Charith_Asalanka          Left                    80
# Match_4             Muhammad_Rizwan         Right                    79
# Match_5           Najibullah_Zadran          Left                    59
# Match_6                  Evin_Lewis          Left                    56
# Match_7             Muhammad_Rizwan         Right                    33
# Match_8                   Jason_Roy         Right                    61
# Match_9               Michael_Leask         Right                    44
# Match_10               David_Warner          Left                    65
# Match_11                  Liton_Das         Right                    40
# Match_12                 Babar_Azam         Right                    51
# Match_13            Pathum_Nissanka         Right                    72
# Match_14                Jos_Buttler         Right                    71
# Match_15           Mohammad_Shahzad         Right                    45
# Match_16             Daryl_Mitchell         Right                    49
# Match_17                Jos_Buttler         Right                   101
# Match_18              Temaba_Bavuma         Right                    31
# Match_19            Muhammad_Rizwan         Right                    79
# Match_20             Martin_Guptill         Right                    93
# Match_21               Rohit_Sharma         Right                    74
# Match_22                Aaron_Finch         Right                    40
# Match_23            Shimron_Hetmyer          Left                    81
# Match_24             Glenn_Phillips         Right                    39
# Match_25                   KL_Rahul         Right                    50
# Match_26               David_Warner          Left                    89
# Match_27      Rassie van der Dussen         Right                    94
# Match_28          Najibullah_Zadran          Left                    73
# Match_29                 Babar_Azam         Right                    66
# Match_30               Rohit_Sharma         Right                    56
# Match_31             Daryl_Mitchell         Right                    72
# Match_32            Muhammad_Rizwan         Right                    67
# Match_33            Kane_Williamson         Right                    85
#
#              strike_rate best_batter_team  target  target_achieved  \
# Match Number
# Match_1           111.10      SouthAfrica     119     Not Achieved
# Match_2           109.10          England      56     Not Achieved
# Match_3           163.20         Srilanka     172     Not Achieved
# Match_4           143.60         Pakistan     152     Not Achieved
# Match_5           173.53      Afghanistan     191         Achieved
# Match_6           160.00          Windies     144     Not Achieved
# Match_7            97.06         Pakistan     135     Not Achieved
# Match_8           160.50          England     125     Not Achieved
# Match_9           162.90         ScotLand     110     Not Achieved
# Match_10          154.76        Australia     155     Not Achieved
# Match_11          102.30       Bangladesh     140     Not Achieved
# Match_12          108.50         Pakistan     148     Not Achieved
# Match_13          124.14         Srilanka     143     Not Achieved
# Match_14          221.80          England     126     Not Achieved
# Match_15          136.36      Afghanistan     161         Achieved
# Match_16          140.00      New_Zealand     111     Not Achieved
# Match_17          150.75          England     164         Achieved
# Match_18          110.70      SouthAfrica      85     Not Achieved
# Match_19          158.00         Pakistan     190         Achieved
# Match_20          166.07      New_Zealand     173         Achieved
# Match_21          157.45            India     211         Achieved
# Match_22          200.00        Australia      74     Not Achieved
# Match_23          150.00          Windies     190         Achieved
# Match_24          185.71      New_Zealand     164         Achieved
# Match_25          263.16            India      86     Not Achieved
# Match_26          158.93        Australia     158     Not Achieved
# Match_27          156.67      SouthAfrica     190         Achieved
# Match_28          152.08      Afghanistan     125     Not Achieved
# Match_29          140.43         Pakistan     190         Achieved
# Match_30          151.35            India     133     Not Achieved
# Match_31          153.19      New_Zealand     167     Not Achieved
# Match_32          128.85         Pakistan     177     Not Achieved
# Match_33          177.08      New_Zealand     173     Not Achieved
#
#                 Player_of_the_match       Winner
# Match Number
# Match_1              Josh_Hazlewood    Australia
# Match_2                   Moeen_Ali      England
# Match_3            Charith_Asalanka     Srilanka
# Match_4                Shaheen_shah     Pakistan
# Match_5            Mujeeb_ur_Rehman  Afghanistan
# Match_6               Anrich_Nortje  SouthAfrica
# Match_7                  Haris_Rauf     Pakistan
# Match_8                   Jason_Roy      England
# Match_9           Ruben_Trumpelmann      Namibia
# Match_10                 Adam_Zampa    Australia
# Match_11            Nicholas_Pooran      Windies
# Match_12                   Asif_Ali     Pakistan
# Match_13             Tabraiz_Shamsi  SouthAfrica
# Match_14               Chris_Jordan      England
# Match_15              Naveen_ul_Haq  Afghanistan
# Match_16                Trent_Boult  New_Zealand
# Match_17                Jos_Buttler      England
# Match_18              Kagiso_Rabada  SouthAfrica
# Match_19            Muhammad_Rizwan     Pakistan
# Match_20             Martin_Guptill  New_Zealand
# Match_21               Rohit_Sharma        India
# Match_22                 Adam_Zampa    Australia
# Match_23            Chrith_Adalanka     Srilanka
# Match_24              James_Neesham  New_Zealand
# Match_25            Ravindra_Jadeja        India
# Match_26               David_Warner    Australia
# Match_27      Rassie_van_der_Dussen  SouthAfrica
# Match_28                Trent_Boult  New_Zealand
# Match_29               Shoaib_Malik     Pakistan
# Match_30            Ravindra_Jadeja        India
# Match_31             Daryl_Mitchell  New_Zealand
# Match_32               Matthew_Wade    Australia
# Match_33             Mitchell_Marsh    Australia
#
# [33 rows x 23 columns]

# %%
#visualize team 1
chart=sns.countplot(df['team_1'])
chart.set_xticklabels(chart.get_xticklabels(), rotation = 45)
plt.show()
# Out:
# /Users/srikar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Visualize team 2 
chart1=sns.countplot(df['team_2'])
chart1.set_xticklabels(chart1.get_xticklabels(),rotation=45)
plt.show()
# Out:
# /Users/srikar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#team1 & target achieved 
team1_achieved=df.groupby(['team_1','target_achieved']).size().reset_index(name="Count")

# %%
plt.figure(figsize = (10,6))
chart = sns.barplot(data = team1_achieved, x = 'team_1', y = 'Count', hue = 'target_achieved', palette = 'Set1')
chart.set_xticklabels(chart.get_xticklabels(), rotation = 45)
plt.title("Team 1 ~ Achievement")
plt.show()

# %%
#team2 and target achieved 
team2_achieved=df.groupby(['team_2','target_achieved']).size().reset_index(name="Count")

# %%
plt.figure(figsize = (10,6))
chart = sns.barplot(data = team2_achieved, x = 'team_2', y = 'Count', hue = 'target_achieved')
chart.set_xticklabels(chart.get_xticklabels(), rotation = 65)
plt.title("Team 2 ~ Achievement")
plt.show()

# %%
sns.countplot(df['stage'])
plt.show()
# Out:
# /Users/srikar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#GroupStage and Target achievement 
stage_achieved=df.groupby(['stage','target_achieved']).size().reset_index(name="Count")

# %%
plt.figure(figsize = (8,6))
sns.barplot(data = stage_achieved, x = 'stage', y = 'Count', hue = 'target_achieved', palette = 'Set2')
chart.set_xticklabels(chart.get_xticklabels(), rotation = 45)
plt.title("Stage of Tournament ~ Achievement")
plt.show()

# %%
#Visualize winner of toss 
chart=sns.countplot(df['Winner_toss'])
chart.set_xticklabels(chart.get_xticklabels(),rotation=45)
plt.show()
# Out:
# /Users/srikar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#GroupWinner toss and Target achievement 
winner_achieved=df.groupby(['Winner_toss','target_achieved']).size().reset_index(name="Count")

# %%
chart=sns.barplot(data=winner_achieved,x='Winner_toss',y='Count',hue='target_achieved')
chart.set_xticklabels(chart.get_xticklabels(),rotation=45)
plt.title('Winner of Toss~Achievement')
plt.show()

# %%
#Visualize toss decision 
sns.countplot(df['Toss_descision'])
plt.show()
# Out:
# /Users/srikar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#group toss decision and target achievement 
toss_achieved=df.groupby(['Toss_descision','target_achieved']).size().reset_index(name="Count")

# %%
chart=sns.barplot(data=toss_achieved,x='Toss_descision',y='Count',hue='target_achieved')
chart.set_xticklabels(chart.get_xticklabels(),rotation=45)
plt.title('TossDecision~target achieved')
plt.show()

# %%
#Visualize time 
sns.countplot(df['time'])
plt.show()
# Out:
# /Users/srikar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#group time and targetachievement 

time_achieved = df.groupby(['time', 'target_achieved']).size().reset_index(name = 'Count')

# %%
#visualize time ~ target achieved
plt.figure(figsize = (8,6))
sns.barplot(data = time_achieved, x = 'time', y = 'Count', hue = 'target_achieved', palette = 'Set2')
plt.title("Time ~ Achievement")
plt.show()

# %%
sns.countplot(df['venue'])
plt.title("Venue of Match")
plt.show()
# Out:
# /Users/srikar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#group venue & target achievement
venue_achieved = df.groupby(['venue', 'target_achieved']).size().reset_index(name = 'Count')

# %%
plt.figure(figsize = (8,6))
sns.barplot(data = venue_achieved, x = 'venue', y = 'Count', hue = 'target_achieved', palette = 'Set1')
plt.title("Venue of Match ~ Achievement")
plt.show()

# %%
#visualize bowling arm
plt.figure(figsize = (8,6))
sns.countplot(df['bowling_arm'], palette = 'Set2')
plt.title("Bowling Arm of Best Bowler")
plt.show()
# Out:
# /Users/srikar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#group bowling arm & target achievement
bowling_achieved = df.groupby(['bowling_arm', 'target_achieved']).size().reset_index(name = 'Count')

# %%
sns.barplot(data = bowling_achieved, x = 'bowling_arm', y = 'Count', hue = 'target_achieved')
plt.title("Bowling Arm ~ Achievement")
plt.legend(bbox_to_anchor = (1.01, 1), borderaxespad = 0)
plt.show()

# %%
#visualize bowling style
plt.figure(figsize = (8,6))
sns.countplot(df['bowling_style'], palette = 'Set1')
plt.title("Bowling Style of Best Bowler")
plt.show()
# Out:
# /Users/srikar/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#group bowling style & target achievement
style_achieved = df.groupby(['bowling_style', 'target_achieved']).size().reset_index(name = 'Count')

# %%
#visualize bowling arm ~ target achieved
plt.figure(figsize = (8,6))
sns.barplot(data = style_achieved, x = 'bowling_style', y = 'Count', hue = 'target_achieved', palette = 'Set2')
plt.title("Bowling Style ~ Achievement")
plt.legend(bbox_to_anchor = (1.01, 1), borderaxespad = 0)
plt.show()

# %%
#handling categorical data
for i in df.columns.tolist():
    df[i] = df[i].astype('category').cat.codes

df.head()
# Out:
#               team_1  team_2  stage  Winner_toss  Toss_descision  time  venue  \
# Match Number
# Match_1            1      10      1            1               1     0      0
# Match_2            2      12      1            3               1     1      1
# Match_3            8       2      1            9               1     0      2
# Match_4            6       4      1            7               1     1      1
# Match_5            0       9      1            0               0     1      2
#
#               avg_temperature  best_bowler  bowling_arm  ...  \
# Match Number                                             ...
# Match_1                     5            9            1  ...
# Match_2                     7            1            1  ...
# Match_3                     8           19            0  ...
# Match_4                     8           18            0  ...
# Match_5                     7           13            1  ...
#
#               best_bowler_country  best_batter  batting_hand  \
# Match Number
# Match_1                         1            1             1
# Match_2                         3            9             1
# Match_3                         2            3             0
# Match_4                         7           16             1
# Match_5                         0           17             0
#
#               high_indvidual_scores  strike_rate  best_batter_team  target  \
# Match Number
# Match_1                           4            5                 8       6
# Match_2                           0            3                 3       0
# Match_3                          21           25                 9      21
# Match_4                          20           11                 6      15
# Match_5                          11           27                 0      25
#
#               target_achieved  Player_of_the_match  Winner
# Match Number
# Match_1                     1                   12       1
# Match_2                     1                   17       2
# Match_3                     1                    3       8
# Match_4                     1                   26       6
# Match_5                     0                   19       0
#
# [5 rows x 23 columns]

# %%
#split data
X = df.drop('target_achieved', axis = 1)
y = df['target_achieved']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (23, 22)
# (23,)
# (10, 22)
# (10,)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics

# %%
#build model
nb = GaussianNB()
# %time nb.fit(X_train, y_train)
accuracy = nb.score(X_test, y_test)
print('Accuracy Score : ', int(accuracy * 100), '%')
# Out:
# CPU times: user 3 ms, sys: 6.15 ms, total: 9.15 ms
# Wall time: 13.9 ms
# Accuracy Score :  80 %

# %%
#prediction
y_pred = nb.predict(X_test)
print(y_pred)
# Out:
# [1 0 1 1 0 0 0 0 1 1]

# %%
#check of MSE & RMSE 
mse = metrics.mean_squared_error(y_test, y_pred)
print('Mean Squared Error : '+ str(mse))
rmse = math.sqrt(metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error : '+ str(rmse))
# Out:
# Mean Squared Error : 0.2
# Root Mean Squared Error : 0.4472135954999579

# %%
#confusion matrix
matrix = metrics.confusion_matrix(y_test, y_pred)
print(matrix)

#heatmap matrix
plt.figure(figsize = (8,6))
sns.heatmap(matrix, annot = True, fmt = '.0f', cmap = 'viridis')
plt.title("Confusion Matrix")
plt.xlabel("Prediction")
plt.ylabel("Actual")
plt.show()
# Out:
# [[3 0]
#  [2 5]]

# %%
#classification report
report = metrics.classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.60      1.00      0.75         3
#            1       1.00      0.71      0.83         7
#
#     accuracy                           0.80        10
#    macro avg       0.80      0.86      0.79        10
# weighted avg       0.88      0.80      0.81        10
